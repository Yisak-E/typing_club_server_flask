# %% [markdown]
# # self generated animations

# %% [markdown]
# ## pulse

# %%
import tkinter as tk

class Pulse:
    def __init__(self, root):
        self.root = root
        self.canvas = tk.Canvas(self.root, bg="gray", height=700, width=700)
        self.canvas.pack()

        points = [

        ]



r = tk.Tk()
pulse = Pulse(r)
root.mainloop()
